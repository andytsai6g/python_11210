# %%
import numpy as np
import pandas as pd
scroes = np.random.randint(50, 100,size=(50,5))
scores_df = pd.DataFrame(scroes,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index=range(1,51))
scores_df
sum_values = scores_df.sum(axis=1)
mean_values = scores_df.mean(axis=1)
scores_df['總分'] = sum_values
scores_df['平均'] = mean_values
scores_df
# Out:
#     國文  英文  數學  地理  歷史   總分    平均
# 1   96  87  95  95  72  445  89.0
# 2   67  72  99  67  71  376  75.2
# 3   74  88  77  93  77  409  81.8
# 4   67  79  91  80  80  397  79.4
# 5   95  64  94  68  73  394  78.8
# 6   62  67  92  92  85  398  79.6
# 7   92  82  71  99  69  413  82.6
# 8   94  82  75  85  74  410  82.0
# 9   57  57  90  74  95  373  74.6
# 10  65  70  84  88  59  366  73.2
# 11  81  63  61  87  99  391  78.2
# 12  75  78  79  87  99  418  83.6
# 13  89  79  58  86  65  377  75.4
# 14  81  60  62  74  89  366  73.2
# 15  68  71  74  67  97  377  75.4
# 16  67  90  63  57  67  344  68.8
# 17  50  58  69  79  68  324  64.8
# 18  52  72  92  54  95  365  73.0
# 19  53  86  84  53  79  355  71.0
# 20  67  85  77  68  67  364  72.8
# 21  83  77  55  82  85  382  76.4
# 22  63  65  94  63  65  350  70.0
# 23  64  70  78  84  68  364  72.8
# 24  97  91  72  74  91  425  85.0
# 25  79  59  95  50  59  342  68.4
# 26  66  58  52  60  98  334  66.8
# ...

# %%
#50~59分
scores_df
scores_df.style\
    .format(precision=2)\
    .highlight_between(left=50,right=59)\
    .to_excel('abc.xlsx')

# %%
#50~59分
scores_df
scores_df.style\
    .format(precision=2)\
    .highlight_between(left=50,right=59)\
# Out:
# <style type="text/css">
# #T_37833_row8_col0, #T_37833_row8_col1, #T_37833_row9_col4, #T_37833_row12_col2, #T_37833_row15_col3, #T_37833_row16_col0, #T_37833_row16_col1, #T_37833_row17_col0, #T_37833_row17_col3, #T_37833_row18_col0, #T_37833_row18_col3, #T_37833_row20_col2, #T_37833_row24_col1, #T_37833_row24_col3, #T_37833_row24_col4, #T_37833_row25_col1, #T_37833_row25_col2, #T_37833_row26_col0, #T_37833_row27_col1, #T_37833_row30_col0, #T_37833_row30_col4, #T_37833_row31_col4, #T_37833_row33_col1, #T_37833_row33_col2, #T_37833_row35_col3, #T_37833_row36_col3, #T_37833_row36_col4, #T_37833_row38_col1, #T_37833_row38_col4, #T_37833_row39_col2, #T_37833_row39_col3, #T_37833_row39_col4, #T_37833_row40_col0, #T_37833_row40_col2, #T_37833_row44_col1, #T_37833_row44_col2, #T_37833_row45_col1, #T_37833_row45_col2, #T_37833_row46_col1, #T_37833_row49_col0, #T_37833_row49_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_37833">
#   <thead>
#     <tr>
# ...

# %%
scores_df
scores_df.style\
    .format(precision=2)\
    .highlight_between(left=50,right=59,props='color:white; background-color:#DB4D6D;')\
    .highlight_max(axis=1,subset=scores_df.columns[:5],props='color:white; background-color:#86C166;')
# Out:
# <style type="text/css">
# ...

# %%
say = np.random.randint(20000, 2000000,size=(50,5))
say_df = pd.DataFrame(say,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index=range(1,51))
say_df
# Out:
#          國文       英文       數學       地理       歷史
# 1   1863867  1647113  1797199   317570   164346
# 2    185242  1973039   947682  1341486   735356
# 3    246600  1201942   246869  1525348  1949454
# 4     36123  1118467  1229424  1177489   466586
# 5   1427592   293352   202576  1304611  1844141
# 6   1646910    71282  1690399  1005870    44150
# 7   1296104   381505  1974039  1932059    65858
# 8    550897  1520119   209306  1503793  1079599
# 9   1212493   939940   470783   108061  1534510
# 10   620964   356615    29258   783164   652098
# 11  1615148   964069   615951  1900293  1873337
# 12   345163  1413315   753619  1320696  1338752
# 13  1838869  1907808  1800911   390066  1130301
# 14   676048  1012686   249473  1497801   406365
# 15   873292  1986275   408383   850479   447840
# 16  1286453  1098394  1172672   545974   709708
# 17   833838  1966050  1761961  1373453   821985
# 18   326348   283313   287489    99798   747965
# 19   898684  1943637  1747285   441471   326952
# ...

# %%
say_df
say_df.style\
    .format(precision=2)\
    .highlight_between(left=1000000,right=1500000,props='color:white; background-color:#DB4D6D;')\
    .highlight_max(axis=1,subset=scores_df.columns[:5],props='color:white; background-color:#86C166;')
# Out:
# <style type="text/css">
# #T_73011_row0_col0, #T_73011_row1_col1, #T_73011_row2_col4, #T_73011_row4_col4, #T_73011_row5_col2, #T_73011_row6_col2, #T_73011_row7_col1, #T_73011_row8_col4, #T_73011_row9_col3, #T_73011_row10_col3, #T_73011_row12_col1, #T_73011_row14_col1, #T_73011_row16_col1, #T_73011_row17_col4, #T_73011_row18_col1, #T_73011_row19_col0, #T_73011_row21_col0, #T_73011_row22_col0, #T_73011_row23_col3, #T_73011_row25_col0, #T_73011_row26_col4, #T_73011_row27_col0, #T_73011_row28_col4, #T_73011_row29_col1, #T_73011_row31_col0, #T_73011_row33_col1, #T_73011_row34_col0, #T_73011_row36_col2, #T_73011_row37_col2, #T_73011_row38_col3, #T_73011_row39_col1, #T_73011_row40_col1, #T_73011_row41_col4, #T_73011_row42_col2, #T_73011_row43_col2, #T_73011_row45_col3, #T_73011_row46_col0, #T_73011_row47_col0, #T_73011_row48_col4 {
#   color: white;
#   background-color: #86C166;
# }
# ...
